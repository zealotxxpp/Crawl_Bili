# %%
import datetime, pymysql
import json as js
import time
import asyncio, aiohttp
from pandas import Series, DataFrame
import pandas as pd

# %%
config = {
      'host':'localhost',
      'port':3306,
      'user':'root',
      'password':'ms020312',
      'db':'test',
      'charset':'utf8mb4'
      }

# %%
def CT_video_status():

    global config

    connection = pymysql.connect(**config)

    try:
        with connection.cursor() as cursor:
            # Create a new record
            sql = """create table video_status(uid varchar(20), aid varchar(20), aid_x varchar(20), view bigint, danmaku int, reply int,
            favorite int, coin int, share int, now_rank int, his_rank int, no_reprint int, copyright int, av_count int, count int,
            total_count int, page int,record_time datetime)
            engine=innodb charset utf8mb4"""
            cursor.execute(sql)

        connection.commit()
        print ('table video_status been created')
    finally:
        connection.close()

# %%
def CT_video_pages():

    global config

    connection = pymysql.connect(**config)

    try:
        with connection.cursor() as cursor:
            # Create a new record
            sql = """create table video_pages(uid varchar(20), aid varchar(20), cid varchar(20), cid_x varchar(20), page int,
            from_source varchar(50), part varchar(50), duration int, vid varchar(20), weblink varchar(100), record_time datetime)engine=innodb charset utf8mb4"""
            cursor.execute(sql)

        connection.commit()
        print ('table video_pages been created')
    finally:
        connection.close()

# %%
async def video_stat_get(aid):

    url = 'https://api.bilibili.com/x/web-interface/archive/stat?aid=%s' % aid

    async with aiohttp.ClientSession() as session:
        try:
            async with session.get(url=url) as resp:
                text = await resp.text()

                if resp.status != 200:
                    raise NameError

                return text

        except aiohttp.client_exceptions.ClientError:
            raise NameError

# %%
async def video_elec_get(aid, mid):

    url = 'https://api.bilibili.com/x/web-interface/elec/show?jsonp=jsonp&aid=%s&mid=%s' % (aid, mid)

    async with aiohttp.ClientSession() as session:
        try:
            async with session.get(url=url) as resp:
                text = await resp.text()

                if resp.status != 200:
                    raise NameError

                return text

        except aiohttp.client_exceptions.ClientError:
            raise NameError

# %%
async def video_pagelist_get(aid):

    url = 'https://api.bilibili.com/x/player/pagelist?aid=%s&jsonp=jsonp' % aid

    async with aiohttp.ClientSession() as session:
        try:
            async with session.get(url=url) as resp:
                text = await resp.text()

                if resp.status != 200:
                    raise NameError

                return text

        except aiohttp.client_exceptions.ClientError:
            raise NameError

# %%
async def video_status_coll(aid, mid, newvideolist):

    global video_status_list
    global video_pages_list

    text_stat = await video_stat_get(aid)
    jstext_stat = js.loads(text_stat,encoding='utf8')
    data_stat = jstext_stat['data']

    text_elec = await video_elec_get(aid, mid)
    jstext_elec = js.loads(text_elec,encoding='utf8')
    data_elec = jstext_elec['data']

    text_pagelist = await video_pagelist_get(aid)
    jstext_pagelist = js.loads(text_pagelist,encoding='utf8')
    data_pagelist = jstext_pagelist['data']



    mid = mid
    aid = data_stat['aid']
    aid_x = str(aid).zfill(12)
    try:
        view = int(data_stat['view'])
    except ValueError:
        view = None
    danmaku = data_stat['danmaku']
    reply = data_stat['reply']
    favorite = data_stat['favorite']
    coin = data_stat['coin']
    share = data_stat['share']
    now_rank = data_stat['now_rank']
    his_rank = data_stat['his_rank']
    no_reprint = data_stat['no_reprint']
    copyright = data_stat['copyright']
    try:
        av_count = data_elec['av_count']
    except TypeError:
        av_count = None
    try:
        count = data_elec['count']
    except TypeError:
        count = None
    try:
        total_count = data_elec['total_count']
    except TypeError:
        total_count = None
    page = len(data_pagelist)



    record_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    temp = [mid,aid,aid_x,view,danmaku,reply,favorite,coin,share,now_rank,his_rank,no_reprint,copyright,av_count,count,
            total_count,page,record_time]

    video_status_list.append(temp)

    print('video aid:%s mid:%s been collected' % (aid ,mid))


    if str(aid) in newvideolist:
        for onepage in data_pagelist:
            uid = mid
            cid = onepage['cid']
            cid_x = str(cid).zfill(12)
            page = onepage['page']
            from_source = onepage['from']
            part = onepage['part']
            duration = onepage['duration']
            vid = onepage['vid']
            weblink = onepage['weblink']

            temp = [uid,aid,cid,cid_x,page,from_source,part,duration,vid,weblink,record_time]

            video_pages_list.append(temp)
            print('page aid:%s mid:%s cid:%s been collected' % (aid ,mid, cid))

# %%
def video_status_insert(video_status_list):

    global config

    connection = pymysql.connect(**config)

    try:
        with connection.cursor() as cursor:

            sql = """INSERT INTO video_status(uid,aid,aid_x,view,danmaku,reply,favorite,coin,share,now_rank,his_rank,no_reprint,copyright,av_count,count,
            total_count,page,record_time)VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""

            try:
                cursor.executemany(sql,video_status_list)
                connection.commit()
                print('INSET %d ROWS in Table video_status' % len(video_status_list))
            except Exception as e:
                print(e)
                connection.rollback()
                raise Exception
    finally:
        connection.close()

# %%
def video_pages_insert(video_pages_list):

    global config

    connection = pymysql.connect(**config)

    try:
        with connection.cursor() as cursor:

            sql = """INSERT INTO video_pages(uid,aid,cid,cid_x,page,from_source,part,duration,vid,weblink,record_time)
            VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""

            try:
                cursor.executemany(sql,video_pages_list)
                connection.commit()
                print('INSET %d ROWS in Table video_pages' % len(video_pages_list))
            except Exception as e:
                print(e)
                connection.rollback()
                raise Exception
    finally:
        connection.close()

# %%
def videolist_get(uid):

    global config

    connection = pymysql.connect(**config)

    cur = connection.cursor(pymysql.cursors.DictCursor)

    sql = "SELECT distinct aid FROM uper_videos WHERE mid = %d"
    cur.execute(sql % uid)

    data = cur.fetchall()
    videolist = []
    if len(data) == 0:
        print('uid: %s has no video in Database' % uid)
        return videolist

    DF = DataFrame(data)
    for i in range(len(DF)):
        videolist.append(DF.iloc[i].values[0])

    print('uid: %s has %s video in Database' % (uid, len(videolist)))
    return videolist

# %%
def newvideolist_get(uid):

    global config

    connection = pymysql.connect(**config)

    cur = connection.cursor(pymysql.cursors.DictCursor)

    sql = "SELECT distinct aid FROM uper_videos b WHERE mid = %d and b.aid not in (SELECT distinct aid FROM video_pages)"
    cur.execute(sql % uid)

    data = cur.fetchall()
    newvideolist = []
    if len(data) == 0:
        print('uid: %s has no new video in Database' % uid)
        return newvideolist

    DF = DataFrame(data)
    for i in range(len(DF)):
        newvideolist.append(DF.iloc[i].values[0])

    print('uid: %s has %s new video in Database' % (uid, len(newvideolist)))
    return newvideolist

# %%
def video_status_update(uid):
    global video_status_list
    global video_pages_list

    videolist = videolist_get(uid)
    newvideolist = newvideolist_get(uid)
    print('\r\n')
    listnum = len(videolist)
    roundnum = (listnum // 10) + 1

    st = 0
    InsertNum1 = 0
    InsertNum2 = 0

    while st < roundnum:
        start = st * 10
        end = start + 10

        video_status_list = []
        video_pages_list = []
        asyncio.set_event_loop(asyncio.new_event_loop())
        loop = asyncio.get_event_loop()
        tasks = asyncio.gather(*[video_status_coll(aid, uid, newvideolist) for aid in videolist[start:end]])
        st = st + 1
        try:
            loop.run_until_complete(tasks)
        except NameError:
            print('too fast too fast')
            loop.close()
            time.sleep(60)
            st = st - 1
            continue
        loop.close()


        try:
            video_status_insert(video_status_list)
            InsertNum1 = InsertNum1 + len(video_status_list)
        except Exception as e:
            print(e)
            return Error

        if len(video_pages_list) == 0:
            continue

        try:
            video_pages_insert(video_pages_list)
            InsertNum2 = InsertNum2 + len(video_pages_list)
        except Exception:
            return



    print ('Totally #%s upper insert %d ROWS in Table video_status' % (uid, InsertNum1))
    print ('Totally #%s upper insert %d ROWS in Table video_pages' % (uid, InsertNum2))

# %%
video_status_list = []
video_pages_list = []

# %%
if __name__ == '__main__':
    time1 = time.time()

    uper_list = [7349]
    for uper in uper_list:
        video_status_update(uper)

    time2 = time.time()
    print('status updated all done ' + 'total_time:' + str(time2 - time1))
# Out:
# uid: 7349 has 427 video in Database
# uid: 7349 has no new video in Database
#
#
# video aid:20457214 mid:7349 been collected
# video aid:20804061 mid:7349 been collected
# video aid:20760130 mid:7349 been collected
# video aid:20745013 mid:7349 been collected
# video aid:20396426 mid:7349 been collected
# video aid:20158445 mid:7349 been collected
# video aid:20291549 mid:7349 been collected
# video aid:20687491 mid:7349 been collected
# video aid:20573687 mid:7349 been collected
# video aid:20090588 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:19385019 mid:7349 been collected
# video aid:19388944 mid:7349 been collected
# video aid:18962159 mid:7349 been collected
# video aid:19384661 mid:7349 been collected
# video aid:19384737 mid:7349 been collected
# video aid:19070224 mid:7349 been collected
# video aid:19748709 mid:7349 been collected
# video aid:19243962 mid:7349 been collected
# video aid:19181551 mid:7349 been collected
# video aid:19381407 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:18491083 mid:7349 been collected
# video aid:18886702 mid:7349 been collected
# video aid:18599650 mid:7349 been collected
# video aid:18390083 mid:7349 been collected
# video aid:18774073 mid:7349 been collected
# video aid:18343047 mid:7349 been collected
# video aid:18938328 mid:7349 been collected
# video aid:18234127 mid:7349 been collected
# video aid:18655251 mid:7349 been collected
# video aid:18147787 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:17861465 mid:7349 been collected
# video aid:18033899 mid:7349 been collected
# video aid:17656823 mid:7349 been collected
# video aid:18106327 mid:7349 been collected
# video aid:17773532 mid:7349 been collected
# video aid:17751783 mid:7349 been collected
# video aid:17908997 mid:7349 been collected
# video aid:17608691 mid:7349 been collected
# video aid:18069721 mid:7349 been collected
# video aid:17621759 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:17303694 mid:7349 been collected
# video aid:17479048 mid:7349 been collected
# video aid:17386029 mid:7349 been collected
# video aid:17027300 mid:7349 been collected
# video aid:16988205 mid:7349 been collected
# video aid:17201420 mid:7349 been collected
# video aid:17161150 mid:7349 been collected
# video aid:17426423 mid:7349 been collected
# video aid:17517493 mid:7349 been collected
# video aid:17319770 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:16605455 mid:7349 been collected
# video aid:16594237 mid:7349 been collected
# video aid:16933135 mid:7349 been collected
# video aid:16633447 mid:7349 been collected
# video aid:16838415 mid:7349 been collected
# video aid:16975814 mid:7349 been collected
# video aid:16757459 mid:7349 been collected
# video aid:16717467 mid:7349 been collected
# video aid:16549347 mid:7349 been collected
# video aid:16508048 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:16422062 mid:7349 been collected
# video aid:16402756 mid:7349 been collected
# video aid:16204647 mid:7349 been collected
# video aid:16191734 mid:7349 been collected
# video aid:16334487 mid:7349 been collected
# video aid:16079394 mid:7349 been collected
# video aid:16293397 mid:7349 been collected
# video aid:16115125 mid:7349 been collected
# video aid:15989407 mid:7349 been collected
# video aid:16140317 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:15716507 mid:7349 been collected
# video aid:15866102 mid:7349 been collected
# video aid:15452231 mid:7349 been collected
# video aid:15508656 mid:7349 been collected
# video aid:15485450 mid:7349 been collected
# video aid:15575757 mid:7349 been collected
# video aid:15698654 mid:7349 been collected
# video aid:15652546 mid:7349 been collected
# video aid:15785984 mid:7349 been collected
# video aid:15904322 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:14184249 mid:7349 been collected
# video aid:15238991 mid:7349 been collected
# video aid:15366955 mid:7349 been collected
# video aid:14785491 mid:7349 been collected
# video aid:15418335 mid:7349 been collected
# video aid:14986338 mid:7349 been collected
# video aid:14747254 mid:7349 been collected
# video aid:14987660 mid:7349 been collected
# video aid:14906728 mid:7349 been collected
# video aid:14961235 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:14491868 mid:7349 been collected
# video aid:14578059 mid:7349 been collected
# video aid:14286833 mid:7349 been collected
# video aid:14219690 mid:7349 been collected
# video aid:14157017 mid:7349 been collected
# video aid:14077787 mid:7349 been collected
# video aid:14726961 mid:7349 been collected
# video aid:14183662 mid:7349 been collected
# video aid:14368182 mid:7349 been collected
# video aid:14692829 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:13626657 mid:7349 been collected
# video aid:14034159 mid:7349 been collected
# video aid:13534526 mid:7349 been collected
# video aid:13589508 mid:7349 been collected
# video aid:13077181 mid:7349 been collected
# video aid:13802783 mid:7349 been collected
# video aid:13257144 mid:7349 been collected
# video aid:13275320 mid:7349 been collected
# video aid:12997517 mid:7349 been collected
# video aid:13905029 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:12695163 mid:7349 been collected
# video aid:12287403 mid:7349 been collected
# video aid:12542790 mid:7349 been collected
# video aid:12069542 mid:7349 been collected
# video aid:12198817 mid:7349 been collected
# video aid:12632865 mid:7349 been collected
# video aid:12970682 mid:7349 been collected
# video aid:12800170 mid:7349 been collected
# video aid:12432514 mid:7349 been collected
# video aid:12213248 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:11454195 mid:7349 been collected
# video aid:11722170 mid:7349 been collected
# video aid:11980868 mid:7349 been collected
# video aid:11563145 mid:7349 been collected
# video aid:11375028 mid:7349 been collected
# video aid:11404420 mid:7349 been collected
# video aid:11763260 mid:7349 been collected
# video aid:11648706 mid:7349 been collected
# video aid:11855390 mid:7349 been collected
# video aid:12002188 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:10679213 mid:7349 been collected
# video aid:10749386 mid:7349 been collected
# video aid:11091686 mid:7349 been collected
# video aid:10842879 mid:7349 been collected
# video aid:11366092 mid:7349 been collected
# video aid:11270505 mid:7349 been collected
# video aid:11351168 mid:7349 been collected
# video aid:11193338 mid:7349 been collected
# video aid:10859770 mid:7349 been collected
# video aid:10993071 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:10511478 mid:7349 been collected
# video aid:9997986 mid:7349 been collected
# video aid:10408668 mid:7349 been collected
# video aid:10238319 mid:7349 been collected
# video aid:10068953 mid:7349 been collected
# video aid:10648940 mid:7349 been collected
# video aid:10160258 mid:7349 been collected
# video aid:10339881 mid:7349 been collected
# video aid:10626930 mid:7349 been collected
# video aid:10133954 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:9943946 mid:7349 been collected
# video aid:9364295 mid:7349 been collected
# video aid:9586660 mid:7349 been collected
# video aid:9748372 mid:7349 been collected
# video aid:9510971 mid:7349 been collected
# video aid:9841703 mid:7349 been collected
# video aid:9909658 mid:7349 been collected
# video aid:9679556 mid:7349 been collected
# video aid:9286874 mid:7349 been collected
# video aid:9429218 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:9167701 mid:7349 been collected
# video aid:9143014 mid:7349 been collected
# video aid:8946440 mid:7349 been collected
# video aid:9007539 mid:7349 been collected
# video aid:8871690 mid:7349 been collected
# video aid:8967941 mid:7349 been collected
# video aid:8809001 mid:7349 been collected
# video aid:9080240 mid:7349 been collected
# video aid:9220921 mid:7349 been collected
# video aid:8924152 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:8674991 mid:7349 been collected
# video aid:8248566 mid:7349 been collected
# video aid:8119794 mid:7349 been collected
# video aid:8294107 mid:7349 been collected
# video aid:8590849 mid:7349 been collected
# video aid:8367843 mid:7349 been collected
# video aid:8731597 mid:7349 been collected
# video aid:8170147 mid:7349 been collected
# video aid:8043705 mid:7349 been collected
# video aid:8529627 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:7603717 mid:7349 been collected
# video aid:7692584 mid:7349 been collected
# video aid:7817478 mid:7349 been collected
# video aid:7541863 mid:7349 been collected
# video aid:7711005 mid:7349 been collected
# video aid:7764849 mid:7349 been collected
# video aid:7928138 mid:7349 been collected
# video aid:7992828 mid:7349 been collected
# video aid:7878305 mid:7349 been collected
# video aid:7652594 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:7236166 mid:7349 been collected
# video aid:7338629 mid:7349 been collected
# video aid:7097736 mid:7349 been collected
# video aid:7440559 mid:7349 been collected
# video aid:7399194 mid:7349 been collected
# video aid:7046892 mid:7349 been collected
# video aid:7084114 mid:7349 been collected
# video aid:7486456 mid:7349 been collected
# video aid:7227176 mid:7349 been collected
# video aid:7444013 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:6903369 mid:7349 been collected
# video aid:7001857 mid:7349 been collected
# video aid:7043734 mid:7349 been collected
# video aid:6957154 mid:7349 been collected
# video aid:6945667 mid:7349 been collected
# video aid:7028267 mid:7349 been collected
# video aid:6864510 mid:7349 been collected
# video aid:6848510 mid:7349 been collected
# video aid:6822527 mid:7349 been collected
# video aid:6836474 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:6810667 mid:7349 been collected
# video aid:6663913 mid:7349 been collected
# video aid:6532334 mid:7349 been collected
# video aid:6714198 mid:7349 been collected
# video aid:6769286 mid:7349 been collected
# video aid:6569506 mid:7349 been collected
# video aid:6754547 mid:7349 been collected
# video aid:6673689 mid:7349 been collected
# video aid:6624330 mid:7349 been collected
# video aid:6728622 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:6376730 mid:7349 been collected
# video aid:6444827 mid:7349 been collected
# video aid:6449540 mid:7349 been collected
# video aid:6361662 mid:7349 been collected
# video aid:6481794 mid:7349 been collected
# video aid:6425341 mid:7349 been collected
# video aid:6385615 mid:7349 been collected
# video aid:6353777 mid:7349 been collected
# video aid:6477889 mid:7349 been collected
# video aid:6463093 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:6265288 mid:7349 been collected
# video aid:6251550 mid:7349 been collected
# video aid:6178101 mid:7349 been collected
# video aid:6203511 mid:7349 been collected
# video aid:6342532 mid:7349 been collected
# video aid:6272462 mid:7349 been collected
# video aid:6216644 mid:7349 been collected
# video aid:6304852 mid:7349 been collected
# video aid:6261940 mid:7349 been collected
# video aid:6289877 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:6089357 mid:7349 been collected
# video aid:6006043 mid:7349 been collected
# video aid:5889002 mid:7349 been collected
# video aid:5862944 mid:7349 been collected
# video aid:6118687 mid:7349 been collected
# video aid:6100656 mid:7349 been collected
# video aid:5953062 mid:7349 been collected
# video aid:5849814 mid:7349 been collected
# video aid:6167310 mid:7349 been collected
# video aid:6069275 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:5552121 mid:7349 been collected
# video aid:5651738 mid:7349 been collected
# video aid:5712370 mid:7349 been collected
# video aid:5611163 mid:7349 been collected
# video aid:5555887 mid:7349 been collected
# video aid:5599984 mid:7349 been collected
# video aid:5832290 mid:7349 been collected
# video aid:5723941 mid:7349 been collected
# video aid:5786841 mid:7349 been collected
# video aid:5678701 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:5433233 mid:7349 been collected
# video aid:5290670 mid:7349 been collected
# video aid:5347545 mid:7349 been collected
# video aid:5237429 mid:7349 been collected
# video aid:5208879 mid:7349 been collected
# video aid:5487254 mid:7349 been collected
# video aid:5385907 mid:7349 been collected
# video aid:5448786 mid:7349 been collected
# video aid:5400993 mid:7349 been collected
# video aid:5252398 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:5139871 mid:7349 been collected
# video aid:4985505 mid:7349 been collected
# video aid:5059491 mid:7349 been collected
# video aid:4980635 mid:7349 been collected
# video aid:5200126 mid:7349 been collected
# video aid:4915905 mid:7349 been collected
# video aid:5068991 mid:7349 been collected
# video aid:5035474 mid:7349 been collected
# video aid:4995530 mid:7349 been collected
# video aid:5113318 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:4902255 mid:7349 been collected
# video aid:4773178 mid:7349 been collected
# video aid:4674180 mid:7349 been collected
# video aid:4708893 mid:7349 been collected
# video aid:4890117 mid:7349 been collected
# video aid:4883987 mid:7349 been collected
# video aid:4702934 mid:7349 been collected
# video aid:4795045 mid:7349 been collected
# video aid:4843879 mid:7349 been collected
# video aid:4814168 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:4553474 mid:7349 been collected
# video aid:4602369 mid:7349 been collected
# video aid:4619254 mid:7349 been collected
# video aid:4570587 mid:7349 been collected
# video aid:4585404 mid:7349 been collected
# video aid:4570340 mid:7349 been collected
# video aid:4565813 mid:7349 been collected
# video aid:4604665 mid:7349 been collected
# video aid:4535216 mid:7349 been collected
# video aid:4633523 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:4430745 mid:7349 been collected
# video aid:4513226 mid:7349 been collected
# video aid:4494648 mid:7349 been collected
# video aid:4468139 mid:7349 been collected
# video aid:4477164 mid:7349 been collected
# video aid:4418120 mid:7349 been collected
# video aid:4482170 mid:7349 been collected
# video aid:4534570 mid:7349 been collected
# video aid:4412400 mid:7349 been collected
# video aid:4499965 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:4366120 mid:7349 been collected
# video aid:4401186 mid:7349 been collected
# video aid:4303025 mid:7349 been collected
# video aid:4338979 mid:7349 been collected
# video aid:4235441 mid:7349 been collected
# video aid:4409210 mid:7349 been collected
# video aid:4361422 mid:7349 been collected
# video aid:4403425 mid:7349 been collected
# video aid:4212089 mid:7349 been collected
# video aid:4273498 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:4118317 mid:7349 been collected
# video aid:4155048 mid:7349 been collected
# video aid:4062471 mid:7349 been collected
# video aid:4110638 mid:7349 been collected
# video aid:4177792 mid:7349 been collected
# video aid:4137022 mid:7349 been collected
# video aid:3977412 mid:7349 been collected
# video aid:4005609 mid:7349 been collected
# video aid:4095870 mid:7349 been collected
# video aid:4038887 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:3640087 mid:7349 been collected
# video aid:3690657 mid:7349 been collected
# video aid:3972990 mid:7349 been collected
# video aid:3578754 mid:7349 been collected
# video aid:3540887 mid:7349 been collected
# video aid:3694863 mid:7349 been collected
# video aid:3949725 mid:7349 been collected
# video aid:3749700 mid:7349 been collected
# video aid:3890471 mid:7349 been collected
# video aid:3644006 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:3327644 mid:7349 been collected
# video aid:3538492 mid:7349 been collected
# video aid:3442047 mid:7349 been collected
# video aid:3494935 mid:7349 been collected
# video aid:3488040 mid:7349 been collected
# video aid:3367258 mid:7349 been collected
# video aid:3479115 mid:7349 been collected
# video aid:3406078 mid:7349 been collected
# video aid:3365939 mid:7349 been collected
# video aid:3397568 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:3252291 mid:7349 been collected
# video aid:3172182 mid:7349 been collected
# video aid:3246402 mid:7349 been collected
# video aid:3322965 mid:7349 been collected
# video aid:3213959 mid:7349 been collected
# video aid:3215206 mid:7349 been collected
# video aid:3142525 mid:7349 been collected
# video aid:3288745 mid:7349 been collected
# video aid:3174548 mid:7349 been collected
# video aid:3185990 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:3004002 mid:7349 been collected
# video aid:3105426 mid:7349 been collected
# video aid:3060717 mid:7349 been collected
# video aid:3038549 mid:7349 been collected
# video aid:2979764 mid:7349 been collected
# video aid:3111702 mid:7349 been collected
# video aid:2959200 mid:7349 been collected
# video aid:3084921 mid:7349 been collected
# video aid:3063686 mid:7349 been collected
# video aid:2954229 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:2950161 mid:7349 been collected
# video aid:2923806 mid:7349 been collected
# video aid:2888542 mid:7349 been collected
# video aid:2918738 mid:7349 been collected
# video aid:2892522 mid:7349 been collected
# video aid:2935018 mid:7349 been collected
# video aid:2820729 mid:7349 been collected
# video aid:2814963 mid:7349 been collected
# video aid:2846923 mid:7349 been collected
# video aid:2891575 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:2596352 mid:7349 been collected
# video aid:2589355 mid:7349 been collected
# video aid:2677231 mid:7349 been collected
# video aid:2738193 mid:7349 been collected
# video aid:2665343 mid:7349 been collected
# video aid:2660126 mid:7349 been collected
# video aid:2696042 mid:7349 been collected
# video aid:2700031 mid:7349 been collected
# video aid:2549102 mid:7349 been collected
# video aid:2765820 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:2403852 mid:7349 been collected
# video aid:2459936 mid:7349 been collected
# video aid:2362656 mid:7349 been collected
# video aid:2352244 mid:7349 been collected
# video aid:2304566 mid:7349 been collected
# video aid:2479419 mid:7349 been collected
# video aid:2522478 mid:7349 been collected
# video aid:2415873 mid:7349 been collected
# video aid:2459781 mid:7349 been collected
# video aid:2415734 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:2270802 mid:7349 been collected
# video aid:1187726 mid:7349 been collected
# video aid:1353069 mid:7349 been collected
# video aid:1616844 mid:7349 been collected
# video aid:1616894 mid:7349 been collected
# video aid:2247430 mid:7349 been collected
# video aid:2173666 mid:7349 been collected
# video aid:1845742 mid:7349 been collected
# video aid:1519660 mid:7349 been collected
# video aid:2249156 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:1053474 mid:7349 been collected
# video aid:808861 mid:7349 been collected
# video aid:1081148 mid:7349 been collected
# video aid:981567 mid:7349 been collected
# video aid:1122315 mid:7349 been collected
# video aid:1070703 mid:7349 been collected
# video aid:860502 mid:7349 been collected
# video aid:929987 mid:7349 been collected
# video aid:1021389 mid:7349 been collected
# video aid:828646 mid:7349 been collected
# INSET 10 ROWS in Table video_status
# video aid:28844 mid:7349 been collected
# video aid:754166 mid:7349 been collected
# video aid:20843765 mid:7349 been collected
# video aid:772666 mid:7349 been collected
# video aid:696528 mid:7349 been collected
# video aid:733644 mid:7349 been collected
# video aid:710419 mid:7349 been collected
# INSET 7 ROWS in Table video_status
# Totally #7349 upper insert 427 ROWS in Table video_status
# Totally #7349 upper insert 0 ROWS in Table video_pages
# status updated all done total_time:36.530089378356934
